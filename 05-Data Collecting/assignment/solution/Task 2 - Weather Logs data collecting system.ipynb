# %%
import csv
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
 with open('messurments_log.csv', 'w') as f:
    fnames = ['temp', 'wind', 'humidity', 'visibility', 'presure', 'time_now']
    writer = csv.DictWriter(f, fieldnames=fnames)
    writer.writeheader()
    for i in range(10):
        url = 'https://eg.freemeteo.com/weather/cairo/current-weather/location/?gid=360630&language=english&country=egypt'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        temp = soup.find('div', attrs={'class': 'temp'}).get_text()
        temp = float(temp.split('°')[0])
        wind = float(soup.find('span', attrs={'class': 'white'}).find('b').get_text().strip())
        stats = soup.find('div', attrs={'class': 'stats'}).get_text()
        for el in stats.split(' '):
            if el.endswith('%'):
                humidity = float(el.split('%')[0])
            elif el.endswith('m'):
                visibility = float(el.split('m')[0])
            elif el.endswith('mb'):
                presure = float(el.split('mb')[0])
        now = datetime.now()
        time_now = now.strftime("%d/%m/%Y %H:%M:%S")

        # Write to CSV file
        ############################################################################
        output = {'temp': temp, 'wind': wind, 'humidity': humidity, 'visibility': visibility, 'presure': presure, 'time_now': time_now}
        writer.writerow(output)
        ############################################################################
        
        print(f'scrapping done for {i+1} times at {time_now}')
        time.sleep(60)   # 60 seconds (1 minute)
# Out:
# scrapping done for 1 times at 04/09/2021 04:58:16
# scrapping done for 2 times at 04/09/2021 04:59:16
# scrapping done for 3 times at 04/09/2021 05:00:17
# scrapping done for 4 times at 04/09/2021 05:01:18
# scrapping done for 5 times at 04/09/2021 05:02:19
# scrapping done for 6 times at 04/09/2021 05:03:19
# scrapping done for 7 times at 04/09/2021 05:04:20
# scrapping done for 8 times at 04/09/2021 05:05:21
# scrapping done for 9 times at 04/09/2021 05:06:22
# scrapping done for 10 times at 04/09/2021 05:07:22

# %%
data = pd.read_csv('messurments_log.csv')
data
# Out:
#    temp  wind  humidity  visibility  presure             time_now
# 0  24.0  15.0      78.0     10000.0   1009.0  04/09/2021 04:58:16
# 1  24.0  15.0      78.0     10000.0   1009.0  04/09/2021 04:59:16
# 2  24.0  15.0      78.0     10000.0   1009.0  04/09/2021 05:00:17
# 3  24.0  15.0      78.0     10000.0   1009.0  04/09/2021 05:01:18
# 4  24.0  15.0      78.0     10000.0   1009.0  04/09/2021 05:02:19
# 5  24.0  11.0      78.0       760.0   1009.0  04/09/2021 05:03:19
# 6  24.0  11.0      78.0       760.0   1009.0  04/09/2021 05:04:20
# 7  24.0  11.0      78.0       760.0   1009.0  04/09/2021 05:05:21
# 8  24.0  11.0      78.0       760.0   1009.0  04/09/2021 05:06:22
# 9  24.0  11.0      78.0       760.0   1009.0  04/09/2021 05:07:22
